# %%
import pandas as pd

# %%
df = pd.read_parquet('/Users/julianeoliveira/Downloads/APS_dengue', engine='pyarrow')

# %%
df.columns
# Out:
# Index(['Uf', 'Ibge', 'Municipio', 'Atendimentos', 'populacao_estimada', 'Ano',
#        'Mes', 'PC_COBERTURA_SF', 'PC_COBERTURA_AB', 'measure_1f_12',
#        'd_measure_1f_12', 'q_measure_1f_12', 'PORTE_MUNICIPIO', 'UBS_Count',
#        'Cód Região de Saúde', 'Nome da Região de Saúde', 'long', 'lat',
#        'NM_MUN', 'SIGLA', 'AREA_KM2', 'Dengue'],
#       dtype='object')

# %%
df.Ano.value_counts()
# Out:
# 2021    65507
# 2020    64986
# 2019    64033
# 2018    63062
# 2017    60238
# 2022    33028
# Name: Ano, dtype: int64

# %%
df.head()
# Out:
#    Uf    Ibge          Municipio  Atendimentos  populacao_estimada   Ano  Mes  \
# 0  CE  230535             ICAPUÍ          2464               19685  2017    1
# 1  PE  261050            PASSIRA          4329               28889  2017    1
# 2  PE  261220          SALGUEIRO          5026               60453  2017    1
# 3  PB  251274            RIACHÃO           776                3607  2017    1
# 4  PA  150307  GARRAFÃO DO NORTE          1137               25363  2017    1
#
#   PC_COBERTURA_SF PC_COBERTURA_AB  measure_1f_12  ...  PORTE_MUNICIPIO  \
# 0             100             100       0.817741  ...          PEQUENO
# 1             100             100       1.276060  ...            MEDIO
# 2           91,82           91,82       0.077403  ...            MEDIO
# 3             100             100       1.246145  ...          PEQUENO
# 4           68,06           68,06       1.917779  ...            MEDIO
#
# ...

# %%
df = pd.read_csv('/Users/julianeoliveira/Downloads/bioclim_temperature_BR.csv')

# %%
df.head()
# Out:
#    geocode  datetime  CHG-bio01-count  CHG-bio01-sum  CHG-bio01-mean  \
# 0   110001      1981              228   68333.032913      299.706285
# 1   110001      1982              228   68295.785206      299.542918
# 2   110001      1983              228   68478.692645      300.345143
# 3   110001      1984              228   68266.720198      299.415439
# 4   110001      1985              228   68301.633596      299.568568
#
#    CHG-bio01-sd  CHG-bio01-min  CHG-bio01-max  CHG-bio01-perc25  \
# 0      0.024697     299.651988     299.811016        299.697557
# 1      0.027094     299.496849     299.604644        299.519437
# 2      0.070353     300.217808     300.463753        300.284675
# 3      0.068574     299.306557     299.528456        299.350799
# 4      0.105628     299.414514     299.741425        299.464984
#
#    CHG-bio01-perc50  ...  CHG-bio11-perc75  CHG-bio11-count_normalized  \
# 0        299.705943  ...        298.189961                3.226254e-08
# ...

# %%
df.datetime.value_counts()
# Out:
# 1981    5569
# 1982    5569
# 2003    5569
# 2004    5569
# 2005    5569
# 2006    5569
# 2007    5569
# 2008    5569
# 2009    5569
# 2010    5569
# 2011    5569
# 2012    5569
# 2013    5569
# 2014    5569
# 2015    5569
# 2016    5569
# 2017    5569
# 2018    5569
# 2019    5569
# 2002    5569
# 2001    5569
# 2000    5569
# 1990    5569
# 1983    5569
# 1984    5569
# 1985    5569
# 1986    5569
# 1987    5569
# 1988    5569
# 1989    5569
# 1991    5569
# 1999    5569
# 1992    5569
# 1993    5569
# 1994    5569
# 1995    5569
# 1996    5569
# 1997    5569
# 1998    5569
# 2020    5569
# Name: datetime, dtype: int64
