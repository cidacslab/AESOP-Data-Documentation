# %%
# Author: Juliane Oliveira

# %%
import pandas as pd

# %%
df = pd.read_fwf('/Users/julianeoliveira/Documents/Projects/AESOP/AESOP datalake/Population/pop_muni_br.csv', header=None, skiprows=[0,1,2])
df[0].str.split(',', expand=True)
# Out:
#                                                      0   \
# 0                                               "Nível"
# 1                                                  "MU"
# 2                                                  "MU"
# 3                                                  "MU"
# 4                                                  "MU"
# ...                                                 ...
# 5727                                              "..."
# 5728  Ex: A produção de feijão em determinado municí...
# 5729                                             "A a Z
# 5730                                        (exceto X)"
# 5731  Ex: O nível de precisão da produção estimada d...
#
#                                                      1   \
# 0                                                "Cód."
# 1                                             "1100015"
# 2                                             "1100023"
# 3                                             "1100031"
# ...

# %%
df1 = df[0].str.split(',', expand=True)

# %%
df = df1[1:5571]

# %%
df = df[[1,2,17,18,19,20,21]]

# %%
df.head()
# Out:
#           1                             2         17        18        19  \
# 1  "1100015"  "Alta Floresta D'Oeste (RO)"   "25437"   "23167"   "22945"
# 2  "1100023"              "Ariquemes (RO)"  "107345"  "106168"  "107863"
# 3  "1100031"                 "Cabixi (RO)"    "6224"    "5438"    "5312"
# 4  "1100049"                 "Cacoal (RO)"   "88507"   "84813"   "85359"
# 5  "1100056"             "Cerejeiras (RO)"   "17934"   "16444"   "16323"
#
#          20        21
# 1   "22728"   "22516"
# 2  "109523"  "111148"
# 3    "5188"    "5067"
# 4   "85893"   "86416"
# 5   "16204"   "16088"

# %%
#df = pd.read_csv('/Users/julianeoliveira/Documents/Projects/AESOP/AESOP datalake/Population/pop_muni_br.csv',header = None,engine='python')
#skipfooter= 10#numero de linhas no final
#skiprows=[0,1,2] + lst

# %%
df = df.rename(columns={1: 'co_ibge', 2: 'muni_name',
                  17:'2017',18:'2018',19:'2019',
                  20:'2020',21:'2021'})

# %%
df.head()
# Out:
#      co_ibge                     muni_name      2017      2018      2019  \
# 1  "1100015"  "Alta Floresta D'Oeste (RO)"   "25437"   "23167"   "22945"
# 2  "1100023"              "Ariquemes (RO)"  "107345"  "106168"  "107863"
# 3  "1100031"                 "Cabixi (RO)"    "6224"    "5438"    "5312"
# 4  "1100049"                 "Cacoal (RO)"   "88507"   "84813"   "85359"
# 5  "1100056"             "Cerejeiras (RO)"   "17934"   "16444"   "16323"
#
#        2020      2021
# 1   "22728"   "22516"
# 2  "109523"  "111148"
# 3    "5188"    "5067"
# 4   "85893"   "86416"
# 5   "16204"   "16088"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 1 to 5570
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   co_ibge    5570 non-null   object
#  1   muni_name  5570 non-null   object
#  2   2017       5570 non-null   object
#  3   2018       5570 non-null   object
#  4   2019       5569 non-null   object
#  5   2020       5566 non-null   object
#  6   2021       5538 non-null   object
# dtypes: object(7)
# memory usage: 304.7+ KB

# %%
df.to_csv('/Users/julianeoliveira/Documents/Projects/AESOP/AESOP datalake/Population/pop_muni_br_2001_2021.csv')

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Nível, Cód., Município, 2001, 2002, 2003, 2004, 2005, 2006, 2008, 2009, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Index: []
#
# [0 rows x 22 columns]
